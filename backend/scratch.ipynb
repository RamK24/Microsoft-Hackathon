# %%
from serpapi import GoogleSearch
from dotenv import load_dotenv
load_dotenv()
import os

params = {
  "engine": "google_jobs",
  "q": "food service worker",
  "location": "Atlanta, GA",
  "hl": "en",
  "api_key": os.getenv("GOOGLE_JOBS_KEY")
}

search = GoogleSearch(params)
results = search.get_dict()
jobs_results = results["jobs_results"]
print(jobs_results)
# Out:
# [{'title': 'Food Service Worker (North/South/Central)', 'company_name': 'Fulton Schools', 'location': 'Atlanta, GA', 'via': 'Fulton County Schools', 'share_link': 'https://www.google.com/search?ibp=htl;jobs&q=food+service+worker&htidocid=hasS245i3zdever6AAAAAA%3D%3D&hl=en-US&shndl=37&shmd=H4sIAAAAAAAA_xXMsQrCMBAGYFz7CIJwo4o2IrjooggWHFw6OJY0Hk015i-5q_RpfFbr8o1f9p1kxwvwoJLTp3VMd6QXJ5rfkNSbEv3omaMmGxa0pitqErbJeUKkAmgCTw9etZO9MSIhb0Stti53eBtErjGYJ2r5U4m3ibtglavtbjPkXWyWs0sfdLxK54Eg1EY6abBR7YqK0w-0uO8GoQAAAA&shmds=v1_AQbUm96Ldk2nza2Mj-1QrXKl4waRA5TyrMtaKC5is1TqgDqGbg&shem=xcxes&source=sh/x/job/li/m1/1#fpstate=tldetail&htivrt=jobs&htiq=food+service+worker&htidocid=hasS245i3zdever6AAAAAA%3D%3D', 'extensions': ['8 days ago', 'Full-time', 'No degree mentioned'], 'detected_extensions': {'posted_at': '8 days ago', 'schedule_type': 'Full-time', 'qualifications': 'No degree mentioned'}, 'description': 'Summary\n\nPrepares, cooks, serves, and stores food in accordance with accepted institutional procedures and Health Department Requirements; Adheres to all meal accountability procedures including cashiering\n\nEssential Duties\n• Prepares cooks, and serves food in accordance with accepted institutional and HACCP procedures\n• Follows daily production schedules, including preparing recipes as written\n• Cleans all utensils and equipment used, disposes of garbage and mops assigned floor areas\n• Utilizes left-over food as directed by the manager and stores all food items properly\n• Utilizes and maintains equipment as trained\n• Follows approved instructions for chemical use in the operation of the program\n• Adheres to Federal, State, and Local policies, procedures, and regulations\n• Adheres to Classified Employees Work Rules and School Nutrition Personnel and Uniform Standards\n• Demonstrates ability to improve job-related skills and takes pride in serving students\n• Completes 6 hours of in-service training yearly and attends all training as schedule through the School Nutrition Department\n• Completes a 30-hour state required Orientation for Nutrition Employee course within the first year of employment\n• Communicates effectively and promotes good public relations with students, teachers, and administrators\n• Works with peers/supervisors in tactful, considerate, and cooperative manner and assists others when needed\n• Performs other duties and responsibilities as assigned by the appropriate administrator\n\nRequired Education\n\nNone required\n\nCertification/Licensure\n\nNone required\n\nExperience Qualifications\n\nNone required; Some food service experience preferred\n\nKnowledge/Skills/Abilities\n• Ability to read and follow recipes\n• Manual dexterity necessary to operate food preparation equipment and perform necessary cleaning\n• Ability to understand and follow directions\n• Good communication and interpersonal skills\n\nWorking Conditions\n• Works in kitchen environment\n• Works with hands in hot water and chemicals approved for use in the School Nutrition Program\n• May involve exposure to extreme heat and cold\n• Adheres to Fulton School Nutrition Personnel & Dress Standards\n• Adheres to additional guidelines outlined in the employee handbook\n\nPhysical Demands\n• Ability to lift and carry a minimum of 50 pounds\n• Ability to lift with the use of a ladder in high places\n• Must be able to properly lift heavy items from a stooping position\n• Must be able to stand and/or move about kitchen for entire shift', 'job_highlights': [{'title': 'Qualifications', 'items': ['Ability to read and follow recipes', 'Manual dexterity necessary to operate food preparation equipment and perform necessary cleaning', 'Ability to understand and follow directions', 'Good communication and interpersonal skills', 'Ability to lift and carry a minimum of 50 pounds', 'Ability to lift with the use of a ladder in high places', 'Must be able to properly lift heavy items from a stooping position', 'Must be able to stand and/or move about kitchen for enti ...

# %%
import requests

ADZUNA_APP_ID = os.getenv("ADZUNA_APP_ID")  # From Adzuna dashboard
ADZUNA_APP_KEY = os.getenv("ADZUNA_KEY")  # From Adzuna dashboard
COUNTRY_CODE = "us"  # Options: us, gb, ca, etc.

def get_adzuna_jobs(job_title="software engineer", location="remote"):
    base_url = f"https://api.adzuna.com/v1/api/jobs/{COUNTRY_CODE}/search/1"

    
    params = {
        "app_id": ADZUNA_APP_ID,
        "app_key": ADZUNA_APP_KEY,
        "what": job_title,
        "where": location,
        "results_per_page": 10,  # Max 50
        "max_days_old": 15,  # Filter by posting date
        "part_time": 1  # 1=Full time, 0=All
    }

    try:
        response = requests.get(base_url, params=params)
        response.raise_for_status()
        data = response.json()
        
        return data.get("results", [])
    
    except requests.exceptions.RequestException as e:
        print(f"Error: {e}")
        return []

# Usage
jobs = get_adzuna_jobs("food worker", "georgia")
print(jobs[0].keys())
# Out:
# dict_keys(['longitude', 'salary_min', 'adref', 'salary_max', 'created', 'description', 'redirect_url', 'id', 'location', 'salary_is_predicted', '__CLASS__', 'company', 'contract_time', 'category', 'title', 'latitude'])

# %%
jobs_results[0]
# Out:
# {'title': 'Food Service Worker (North/South/Central)',
#  'company_name': 'Fulton Schools',
#  'location': 'Atlanta, GA',
#  'via': 'Fultonschools.org - Fulton County Schools',
#  'share_link': 'https://www.google.com/search?ibp=htl;jobs&q=food+service+worker&htidocid=hasS245i3zdever6AAAAAA%3D%3D&hl=en-US&shndl=37&shmd=H4sIAAAAAAAA_xXMsQrCMBAGYFz7CIJwo4o2IrjooggWHFw6OJY0Hk015i-5q_RpfFbr8o1f9p1kxwvwoJLTp3VMd6QXJ5rfkNSbEv3omaMmGxa0pitqErbJeUKkAmgCTw9etZO9MSIhb0Stti53eBtErjGYJ2r5U4m3ibtglavtbjPkXWyWs0sfdLxK54Eg1EY6abBR7YqK0w-0uO8GoQAAAA&shmds=v1_AQbUm96Ldk2nza2Mj-1QrXKl4waRA5TyrMtaKC5is1TqgDqGbg&source=sh/x/job/li/m1/1#fpstate=tldetail&htivrt=jobs&htiq=food+service+worker&htidocid=hasS245i3zdever6AAAAAA%3D%3D',
#  'extensions': ['8 days ago', 'Full-time', 'No degree mentioned'],
#  'detected_extensions': {'posted_at': '8 days ago',
#   'schedule_type': 'Full-time',
#   'qualifications': 'No degree mentioned'},
#  'description': 'Summary\n\nPrepares, cooks, serves, and stores food in accordance with accepted institutional procedures and Health Department Requirements; Adheres to all meal accountability procedures including cashiering\n\nEssential Duties\n• Prepares cooks, and serves food in accordance with accepted institutional and HACCP procedures\n• Follows daily production schedules, including preparing recipes as written\n• Cleans all utensils and equipment used, disposes of garbage and mops assigned floor areas\n• Utilizes left-over food as directed by the manager and stores all food items properly\n• Utilizes and maintains equipment as trained\n• Follows approved instructions for chemical use in the operation of the program\n• Adheres to Federal, State, and Local policies, procedures, and regulations\n• Adheres to Classified Employees Work Rules and School Nutrition Personnel and Uniform Standards\n• Demonstrates ability to improve job-related skills and takes pride in serving students\n• Completes 6 hours of in-service training yearly and attends all training as schedule through the School Nutrition Department\n• Completes a 30-hour state required Orientation for Nutrition Employee course within the first year of employment\n• Communicates effectively and promotes good public relations with students, teachers, and administrators\n• Works with peers/supervisors in tactful, considerate, and cooperative manner and assists others when needed\n• Performs other duties and responsibilities as assigned by the appropriate administrator\n\nRequired Education\n\nNone required\n\nCertification/Licensure\n\nNone required\n\nExperience Qualifications\n\nNone required; Some food service experience preferred\n\nKnowledge/Skills/Abilities\n• Ability to read and follow recipes\n• Manual dexterity necessary to operate food preparation equipment and perform necessary cleaning\n• Ability to understand and follow directions\n• Good communication and interpersonal skills\n\nWorking Conditions\n• Works in kitchen environment\n• Works with hands in hot water and chemicals approved for use in the School Nutrition Program\n• May involve exposure to extreme heat and cold\n• Adheres to Fulton School Nutrition Personnel & Dress Standards\n• Adheres to additional guidelines outlined in the employee handbook\n\nPhysical Demands\n• Ability to lift and carry a minimum of 50 pounds\n• Ability to lift with the use of a ladder in high places\n• Must be able to properly lift heavy items from a stooping position\n• Must be able to stand and/or move about kitchen for entire shift',
#  'job_highlights': [{'title': 'Qualifications',
#    'items': ['Ability to read and follow recipes',
#     'Manual dexterity necessary to operate food preparation equipment and perform necessary cleaning',
#     'Ability to understand and follow directions',
#     'Good communication and interpersonal skills',
#     'Ability to lift and carry a minimum of 50 pounds',
#     'Ability to lift with the use of a ladder in high places',
#     'Must be able to properly lift heavy items from a stooping position',
#     'Must be able to stand and/or move about kitchen for entire shift']},
#   {'title': 'Responsibilities',
#    'items': ['Prepares, cooks, serves, and stores food in accordance with accepted institutional procedures and Health Department Requirements; Adheres to all meal accountability procedures including cashiering',
#     'Prepares cooks, and serves food in accordance with accepted institutional and HACCP procedures',
#     'Follows daily production schedules, including preparing recipes as written',
#     'Cleans all utensils and equipment used, disposes of garbage and mops assigned floor areas',
#     'Utilizes left-over food as directed by the manager and stores all food items properly',
#     'Utilizes and maintains equipment as trained',
#     'Follows approved instructions for chemical use in the operation of the program',
#     'Adheres to Federal, State, and Local policies, procedures, and regulations',
#     'Adheres to Classified Employees Work Rules and School Nutrition Personnel and Uniform Standards',
#     'Demonstrates ability to improve job-related skills and takes pride in serving students',
#     'Completes 6 hours of in-service training yearly and attends all training as schedule through the School Nutrition Department',
#     'Completes a 30-hour state required Orientation for Nutrition Employee course within the first year of employment',
#     'Communicates effectively and promotes good public relations with students, teachers, and administrators',
#     'Works with peers/supervisors in tactful, considerate, and cooperative manner and assists others when needed',
#     'Performs other duties and responsibilities as assigned by the appropriate administrator',
#     'Works in kitchen environment',
#     'Works with hands in hot water and chemicals approved for use in the School Nutrition Program',
#     'May involve exposure to extreme heat and cold',
#     'Adheres to Fulton School Nutrition Personnel & Dress Standards',
#     'Adheres to additional guidelines outlined in the employee handbook']}],
#  'apply_options': [{'title': 'Fultonschools.org - Fulton County Schools',
#    'link': 'https://jobs.fultonschools.org/job/Atlanta-Food-Service-Worker-%28NorthSouthCentral%29-GA-30339/1103667400/?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic'},
#   {'title': 'Sodexo Jobs',
#    'link': 'https://jobs.us.sodexo.com/food-service-worker/job/28850836?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic'},
#   {'title': 'Indeed',
#    'link': 'https://www.indeed.com/viewjob?jk=c7e70f72f14b7b44&utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic'},
#   {'title': 'Compass Group',
#    'link': 'https://jobs.compassgroupcareers.com/United_States/job/Atlanta-FOOD-SERVICE-WORKER-%28FULL-TIME%29-GA-30327-2428/1247756000/?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic'},
#   {'title': 'ZipRecruiter',
#    'link': 'https://www.ziprecruiter.com/c/Fulton-County-Schools/Job/Food-Service-Worker-(North-South-Central)/-in-Atlanta,GA?jid=5361996b334d460e&utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic'},
#   {'title': 'Glassdoor',
#    'link': 'https://www.glassdoor.com/job-listing/food-service-worker-north-south-central-fulton-county-schools-JV_IC1155583_KO0,39_KE40,61.htm?jl=1009009179098&utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic'},
#   {'title': 'LinkedIn',
#    'link': 'https://www.linkedin.com/jobs/view/food-service-utility-full-time-at-flik-hospitality-group-4161203207?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic'},
#   {'title': 'LocalJobs.com',
#    'link': 'https://www.localjobs.com/job/atlanta-ga-food-service-utility-full-time-6?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic'}],
#  'job_id': ''}

# %%
print(jobs[4]['description'])
# Out:
# Role: Food Service Worker Pay Rate: Join Healthcare Services Group (HCSG) as a Food Service Worker/Kitchen Helper/Dietary Aide, where you will assist in preparing and serving meals for residents in a long-term care facility. At HCSG, we are passionate about positively impacting the communities we serve. If you share our commitment to excellence and enhancing customer and resident experiences, join us and make a difference Available Benefits For All Employees Free Telemedicine Free Prescription …

# %%
jobs[3]
# Out:
# {'location': {'display_name': 'Augusta, Richmond County',
#   '__CLASS__': 'Adzuna::API::Response::Location',
#   'area': ['US', 'Georgia', 'Richmond County', 'Augusta']},
#  'id': '5073542091',
#  'redirect_url': 'https://www.adzuna.com/details/5073542091?utm_medium=api&utm_source=3a0b89cd',
#  'description': 'We are hiring for Substitute Food Service Workers in the Richmond County School System. Remember that school district employee who made a difference in your life? Now it’s your turn Substitutes are essential in ensuring students continue to learn and grow every day. Substitute Food Service Workers may also be known as Culinary Workers, Cafeteria Workers, or School Nutrition Workers. Working in a school district is rewarding. We would love for you to join our team. Minimum requirements: Must be …',
#  'latitude': 33.473754,
#  'category': {'tag': 'hospitality-catering-jobs',
#   '__CLASS__': 'Adzuna::API::Response::Category',
#   'label': 'Hospitality & Catering Jobs'},
#  'title': 'Substitute Food Service Worker- Augusta Georgia',
#  'contract_time': 'part_time',
#  '__CLASS__': 'Adzuna::API::Response::Job',
#  'company': {'__CLASS__': 'Adzuna::API::Response::Company',
#   'display_name': 'Kelly Services'},
#  'salary_is_predicted': '0',
#  'longitude': -82.012604,
#  'created': '2025-03-04T04:29:13Z',
#  'salary_max': 21299,
#  'adref': 'eyJhbGciOiJIUzI1NiJ9.eyJzIjoieEp3dVQ1VUQ4QkdzWU4wVjdLbUxfUSIsImkiOiI1MDczNTQyMDkxIn0.6JROA7Os14VsAVjHVf0d27P1h7YZ0759KKE1VJsShbg',
#  'salary_min': 21299}

# %%
from assistant import get_embeddings

# %%
print(jobs[3]['description'])
# Out:
# We are hiring for Substitute Food Service Workers in the Richmond County School System. Remember that school district employee who made a difference in your life? Now it’s your turn Substitutes are essential in ensuring students continue to learn and grow every day. Substitute Food Service Workers may also be known as Culinary Workers, Cafeteria Workers, or School Nutrition Workers. Working in a school district is rewarding. We would love for you to join our team. Minimum requirements: Must be …

# %%
out = get_embeddings(['This is a role for test', 'this two'])

# %%
len(out.data[0].embedding)
# Out:
# 1536

# %%
z = out.model_dump_json(indent=2)

# %%
z
# Out:
# '{\n  "data": [\n    {\n      "embedding": [\n        -0.0043913936242461205,\n        -0.006803615018725395,\n        -0.010257862508296967,\n        -0.0007176612853072584,\n        -0.033777866512537,\n        0.030286405235528946,\n        -0.01636115461587906,\n        0.007733995094895363,\n        -0.0062318542040884495,\n        -0.03339894860982895,\n        0.011401384137570858,\n        -0.00649236049503088,\n        0.014006447978317738,\n        -0.0048278262838721275,\n        -0.0033375266939401627,\n        -0.0017609555507078767,\n        0.03372373804450035,\n        0.003467779839411378,\n        0.0017524975119158626,\n        -0.013661361299455166,\n        -0.020691649988293648,\n        0.006708885543048382,\n        -0.0023107256274670362,\n        0.019189510494470596,\n        -0.029149651527404785,\n        -0.01621229387819767,\n        0.009073742665350437,\n        -0.04674229025840759,\n        0.0045571704395115376,\n        -0.01775503344833851,\n        0.0210164375603199,\n        -0.01822868175804615,\n        0.0007599513046443462,\n        -0.043250828981399536,\n        0.00032098108204081655,\n        0.0003558703465387225,\n        0.0018793675117194653,\n        -0.009236135520040989,\n        0.014886079356074333,\n        0.0056228782050311565,\n        -0.0005298936739563942,\n        0.022897496819496155,\n        -0.005734523758292198,\n        -0.03486049175262451,\n        0.004888724070042372,\n        -0.0020096206571906805,\n        0.0013676586095243692,\n        -0.02426430955529213,\n        -0.01837754249572754,\n        0.006258919835090637,\n        0.02287043072283268,\n        0.0005717608146369457,\n        -0.039163921028375626,\n        -0.003239413956180215,\n        -0.012260716408491135,\n        0.014520694501698017,\n        0.000301104795653373,\n        0.016510015353560448,\n        0.01982555165886879,\n        0.0015461223665624857,\n        -0.0207999125123024,\n        -0.006989690940827131,\n        -0.009540623985230923,\n        0.007537769619375467,\n        0.004523338284343481,\n        0.007970819249749184,\n        0.006803615018725395,\n        0.005771738942712545,\n        -0.007429507095366716,\n        0.004181635100394487,\n        0.030692389234900475,\n        -0.005223660729825497,\n        0.00885045062750578,\n        0.007415974047034979,\n        0.035077016800642014,\n        -0.002172014443203807,\n        -0.010623247362673283,\n        -0.004113971255719662,\n        0.0018201615894213319,\n        -0.004766928497701883,\n        0.01936543732881546,\n        -0.012977954931557178,\n        -0.02757984586060047,\n        0.0306111928075552,\n        0.0013279059203341603,\n        0.00826177466660738,\n        0.01853993535041809,\n        0.026970870792865753,\n        -0.010440555401146412,\n        -0.004594385623931885,\n        0.010081935673952103,\n        0.0028655703645199537,\n        
share_link': 'https://www.google.com/search?ibp=htl;jobs&q=food+service+worker&htidocid=hasS245i3zdever6AAAAAA%3D%3D&hl=en-US&shndl=37&shmd=H4sIAAAAAAAA_xXMsQrCMBAGYFz7CIJwo4o2IrjooggWHFw6OJY0Hk015i-5q_RpfFbr8o1f9p1kxwvwoJLTp3VMd6QXJ5rfkNSbEv3omaMmGxa0pitqErbJeUKkAmgCTw9etZO9MSIhb0Stti53eBtErjGYJ2r5U4m3ibtglavtbjPkXWyWs0sfdLxK54Eg1EY6abBR7YqK0w-0uO8GoQAAAA&shmds=v1_AQbUm96Ldk2nza2Mj-1QrXKl4waRA5TyrMtaKC5is1TqgDqGbg&shem=xcxes&source=sh/x/job/li/m1/1#fpstate=tldetail&htivrt=jobs&htiq=food+service+worker&htidocid=hasS245i3zdever6AAAAAA%3D%3D',
#   'extensions': ['8 days ago', 'Full-time', 'No degree mentioned'],
#   'detected_extensions': {'posted_at': '8 days ago',
#    'schedule_type': 'Full-time',
#    'qualifications': 'No degree mentioned'},
#   'description': 'Summary\n\nPrepares, cooks, serves, and stores food in accordance with accepted institutional procedures and Health Department Requirements; Adheres to all meal accountability procedures including cashiering\n\nEssential Duties\n• Prepares cooks, and serves food in accordance with accepted institutional and HACCP procedures\n• Follows daily production schedules, including preparing recipes as written\n• Cleans all utensils and equipment used, disposes of garbage and mops assigned floor areas\n• Utilizes left-over food as directed by the manager and stores all food items properly\n• Utilizes and maintains equipment as trained\n• Follows approved instructions for chemical use in the operation of the program\n• Adheres to Federal, State, and Local policies, procedures, and regulations\n• Adheres to Classified Employees Work Rules and School Nutrition Personnel and Uniform Standards\n• Demonstrates ability to improve job-related skills and takes pride in serving students\n• Completes 6 hours of in-service training yearly and attends all training as schedule through the School Nutrition Department\n• Completes a 30-hour state required Orientation for Nutrition Employee course within the first year of employment\n• Communicates effectively and promotes good public relations with students, teachers, and administrators\n• Works with peers/supervisors in tactful, considerate, and cooperative manner and assists others when needed\n• Performs other duties and responsibilities as assigned by the appropriate administrator\n\nRequired Education\n\nNone required\n\nCertification/Licensure\n\nNone required\n\nExperience Qualifications\n\nNone required; Some food service experience preferred\n\nKnowledge/Skills/Abilities\n• Ability to read and follow recipes\n• Manual dexterity necessary to operate food preparation equipment and perform necessary cleaning\n• Ability to understand and follow directions\n• Good communication and interpersonal skills\n\nWorking Conditions\n• Works in kitchen environment\n• Works with hands in hot water and chemicals approved for use in the School Nutrition Program\n• May involve exposure to extreme heat and cold\n• Adheres to Fulton School Nutrition Personnel & Dress Standards\n• Adheres to additional guidelines outlined in the employee handbook\n\nPhysical Demands\n• Ability to lift and carry a minimum of 50 pounds\n• Ability to lift with the use of a ladder in high places\n• Must be able to properly lift heavy items from a stooping position\n• Must be able to stand and/or move about kitchen for entire shift',
#   'job_highlights': [{'title': 'Qualifications',
#     'items': ['Ability to read and follow recipes',
#      'Manual dexterity necessary to operate food preparation equipment and perform necessary cleaning',
#      'Ability to understand and follow directions',
#      'Good communication and interpersonal skills',
#      'Ability to lift and carry a minimum of 50 pounds',
#      'Ability to lift with the use of a ladder in high places',
#      'Must be able to properly lift heavy items from a stooping position',
#      'Must be able to stand and/or move about kitchen for entire shift']},
#    {'title': 'Responsibilities',
#     'items': ['Prepares, cooks, serves, and stores food in accordance with accepted institutional procedures and Health Department Requirements; Adheres to all meal accountability procedures including cashiering',
#      'Prepares cooks, and serves food in accordance with accepted institutional and HACCP procedures',
#      'Follows daily production schedules, including preparing recipes as written',
#      'Cleans all utensils and equipment used, disposes of garbage and mops assigned floor areas',
#      'Utilizes left-over food as directed by the manager and stores all food items properly',
#      'Utilizes and maintains equipment as trained',
#      'Follows approved instructions for chemical use in the operation of the program',
#      'Adheres to Federal, State, and Local policies, procedures, and regulations',
#      'Adheres to Classified Employees Work Rules and School Nutrition Personnel and Uniform Standards',
#      'Demonstrates ability to improve job-related skills and takes pride in serving students',
#      'Completes 6 hours of in-service training yearly and attends all training as schedule through the School Nutrition Department',
#      'Completes a 30-hour state required Orientation for Nutrition Employee course within the first year of employment',
#      'Communicates effectively and promotes good public relations with students, teachers, and administrators',
#      'Works with peers/supervisors in tactful, considerate, and cooperative manner and assists others when needed',
#      'Performs other duties and responsibilities as assigned by the appropriate administrator',
#      'Works in kitchen environment',
#      'Works with hands in hot water and chemicals approved for use in the School Nutrition Program',
#      'May involve exposure to extreme heat and cold',
#      'Adheres to Fulton School Nutrition Personnel & Dress Standards',
#      'Adheres to additional guidelines outlined in the employee handbook']}],
#   'apply_options': [{'title': 'Fulton County Schools',
#     'link': 'https://jobs.fultonschools.org/job/Atlanta-Food-Service-Worker-%28NorthSouthCentral%29-GA-30339/1103667400/?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic'},
#    {'title': 'Sodexo Jobs',
#     'link': 'https://jobs.us.sodexo.com/food-service-worker/job/28850836?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic'},
#    {'title': 'Indeed',
#     'link': 'https://www.indeed.com/viewjob?jk=c7e70f72f14b7b44&utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic'},
#    {'title': 'Compass Group',
#     'link': 'https://jobs.compassgroupcareers.com/United_States/job/Atlanta-FOOD-SERVICE-WORKER-%28FULL-TIME%29-GA-30327-2428/1247756000/?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic'},
#    {'title': 'ZipRecruiter',
#     'link': 'https://www.ziprecruiter.com/c/Fulton-County-Schools/Job/Food-Service-Worker-(North-South-Central)/-in-Atlanta,GA?jid=5361996b334d460e&utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic'},
#    {'title': 'Glassdoor',
#     'link': 'https://www.glassdoor.com/job-listing/food-service-worker-north-south-central-fulton-county-schools-JV_IC1155583_KO0,39_KE40,61.htm?jl=1009009179098&utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic'},
#    {'title': 'LinkedIn',
#     'link': 'https://www.linkedin.com/jobs/view/food-service-utility-full-time-at-flik-hospitality-group-4161203207?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic'},
#    {'title': 'LocalJobs.com',
#     'link': 'https://www.localjobs.com/job/atlanta-ga-food-service-utility-full-time-6?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic'}],
#   'job_id': ''},
#  {'title': 'Food Service Worker',
#   'company_name': 'Sodexo',
#   'location': 'East Point, GA',
#   'via': 'Sodexo Jobs',
#   'share_link': 'https://www.google.com/search?ibp=htl;jobs&q=food+service+worker&htidocid=_XTK8T3SM4a2N0jRAAAAAA%3D%3D&hl=en-US&shndl=37&shmd=H4sIAAAAAAAA_xXEsQrCMBAGYFz7BOJ0c9FEBBedHLTgJHRwLEl6tKkxf8kd0t0XF7_hq76rqr4BPbVcPjEwPVFeXGhHd3gSdiWMhEwNMCTenEfVWU7WiiQziDqNwQS8LTJ7LHaCl3-djK7wnJxydzjuFzPnoV636HkBxUxXJ0oPxKxbai4_Ouo944YAAAA&shmds=v1_AQbUm94ONmiQWH1lGLJ8KC3TK4qXZ3v1bmkSFzd7JkcRDCB4sA&shem=xcxes&source=sh/x/job/li/m1/1#fpstate=tldetail&htivrt=jobs&htiq=food+service+worker&htidocid=_XTK8T3SM4a2N0jRAAAAAA%3D%3D',
#   'extensions': ['5 days ago',
#    '15 an hour',
#    'Full-time',
#    'No degree mentioned',
#    'Paid time off',
#    'Health insurance',
#    'Dental insurance'],
#   'detected_extensions': {'posted_at': '5 days ago',
#    'salary': '15 an hour',
#    'schedule_type': 'Full-time',
#    'qualifications': 'No degree mentioned',
#    'paid_time_off': True,
#    'health_insurance': True,
#    'dental_coverage': True},
#   'description': 'Location Name: DELTA SKY CLUB - ATL - 49870006\n\nLocation ID: 49870006\n\nFood Service Worker\n\nLocation: DELTA SKY CLUB - ATL - 49870006\n\nWorkdays/shifts: Varying shifts, days/hours (open availability preferred). More details will be provided during the interview process.\n\nEmployment Type: Full-time\n\nPay Range: $15 per hour - $15 per hour\n\nWorking with SodexoMagic is more than a job; it’s a chance to be part of something greater because we believe our everyday actions have a big impact. You belong in a company that allows you to act with purpose and thrive in your own way.\n\nWhat You’ll Do: As a Food Service Worker at SodexoMagic, you are a pair of helping hands and a good mood motivator. In this role, you will prepare and serve a variety of vibrant menus and ensure all working areas are kept clean and tidy. Your welcoming customer service puts a smile on people\'s faces and makes an impact in their everyday lives.\n\nResponsibilities include:\n• May work anywhere on property where food is prepared or served. Assist in setup and serving of food from counters and steamtables.\n• Set up stations with entrées, soups, salads, breads, condiments, other food products and utensils and provide general stocking duties in service area.\n• Clean and sanitize equipment and work stations\n• Attends work and shows for scheduled shift on time with satisfactory regularity\n• Other duties may be assigned and can differ among accounts, depending on business necessities and client requirements.\n\nWhat You Bring:\n• Successful candidates will be team-oriented, adaptable, reliable, and nurturers of a healthy/safe working environment for all.\n• No previous work experience required.\n\nLink to full Job description\n\nWhat We Offer:\n• Flexible and supportive work environment, so you can be home for life’s important moments.\n• Access to ongoing training/development and advancement opportunities to turn your job into a career\n• Full array of benefits that support you and your family’s wellbeing, including paid time off, holidays, medical, dental, vision, tuition reimbursement, 401k, discount programs, and more.\n• In addition to SodexoMagic’s standard, some locations may offer additional site-specific benefits, including free "shift" meals (and/or allowances/per diems), uniforms, safety shoes, public transportation support and/or parking.\n\nLink to benefits summary\n\nOverall, SodexoMagic strives to offer comprehensive summaries of our benefits packages and detailed descriptions of the positions candidates are applying for. However, due to the contractual nature of our business, some job duties and employee benefits may vary based on the unit/work location. We encourage you to discuss any questions about SodexoMagic’s benefit offerings during the interview process.\n\nWho we are:\n\nSodexoMagic is the joint venture partnership between NBA Hall of Famer, Earvin "Magic" Johnson, and SodexoMagic. As a certified minority company, we deliver food, facilities management and integrated services to corporations, healthcare facilities, K-12 schools, colleges and universities and aviation lounges. This strategic alliance between Magic Johnson Enterprises and SodexoMagic, Inc., enables us to deliver creative solutions to our clients along with our local partners throughout the communities we serve.\n\nOur company values you for you; you will be treated fairly and with respect, and you can be yourself. You will have your ideas count and your opinions heard because we can be a stronger team when you’re happy at work. This is why we embrace diversity and inclusion as core values, fostering an environment where all employees are valued and respected. We are committed to providing equal employment opportunities to individuals regardless of race, color, religion, national origin, age, sex, gender identity, pregnancy, disability, sexual orientation, military status, protected veteran status, or any other characteristic protected by ap ...
#   'job_highlights': [{'title': 'Qualifications',
#     'items': ['Successful candidates will be team-oriented, adaptable, reliable, and nurturers of a healthy/safe working environment for all',
#      'No previous work experience required']},
#    {'title': 'Benefits',
#     'items': ['Pay Range: $15 per hour - $15 per hour',
#      'Flexible and supportive work environment, so you can be home for life’s important moments',
#      'Access to ongoing training/development and advancement opportunities to turn your job into a career',
#      'Full array of benefits that support you and your family’s wellbeing, including paid time off, holidays, medical, dental, vision, tuition reimbursement, 401k, discount programs, and more',
#      'In addition to SodexoMagic’s standard, some locations may offer additional site-specific benefits, including free "shift" meals (and/or allowances/per diems), uniforms, safety shoes, public transportation support and/or parking']},
#    {'title': 'Responsibilities',
#     'items': ['In this role, you will prepare and serve a variety of vibrant menus and ensure all working areas are kept clean and tidy',
#      "Your welcoming customer service puts a smile on people's faces and makes an impact in their everyday lives",
#      'May work anywhere on property where food is prepared or served',
#      'Assist in setup and serving of food from counters and steamtables',
#      'Set up stations with entrées, soups, salads, breads, condiments, other food products and utensils and provide general stocking duties in service area',
#      'Clean and sanitize equipment and work stations',
#      'Attends work and shows for scheduled shift on time with satisfactory regularity',
#      'Other duties may be assigned and can differ among accounts, depending on business necessities and client requirements']}],
#   'apply_options': [{'title': 'Sodexo Jobs',
#     'link': 'https://jobs.us.sodexo.com/food-service-worker/job/28180282?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic'},
#    {'title': 'Indeed',
#     'link': 'https://www.indeed.com/viewjob?jk=1163ef4d7d3dcc53&utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic'},
#    {'title': 'The Muse',
#     'link': 'https://www.themuse.com/jobs/sodexo/food-service-worker-c37437?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic'},
#    {'title': 'Glassdoor',
#     'link': 'https://www.glassdoor.com/job-listing/food-service-worker-sodexomagic-JV_IC1166812_KO0,19_KE20,31.htm?jl=1009263861154&utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic'},
#    {'title': 'LinkedIn',
#     'link': 'https://www.linkedin.com/jobs/view/food-service-worker-at-sodexo-3945644250?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic'},
#    {'title': 'Our Ability Jobs',
#     'link': 'https://ourability.jobs/east-point-ga/food-service-worker/1006EB633F40494E95D98124CD82995F/job/?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic'},
#    {'title': 'Sodexo.paradox.ai',
#     'link': 'https://sodexo.paradox.ai/co/Sodexo1/Job?job_id=P27-980055-5&utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic'},
#    {'title': 'Fairygodboss',
#     'link': 'https://fairygodboss.com/jobs/sodexo/food-service-worker-71784fd5a825dd2817933cf9b3712084?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic'}],
#   'job_id': 'eyJqb2JfdGl0bGUiOiJGb29kIFNlcnZpY2UgV29ya2VyIiwiY29tcGFueV9uYW1lIjoiU29kZXhvIiwiYWRkcmVzc19jaXR5IjoiRWFzdCBQb2ludCwgR0EiLCJodGlkb2NpZCI6Il9YVEs4VDNTTTRhMk4walJBQUFBQUE9PSIsInV1bGUiOiJ3K0NBSVFJQ0lZUVhSc1lXNTBZU3hIUVN4VmJtbDBaV1FnVTNSaGRHVnoiLCJobCI6ImVuIn0='},
#  {'title': 'Food Service Worker - Georgia Tech',
#   'company_name': 'Proof Of The Pudding',
#   'location': 'Atlanta, GA',
#   'via': 'Indeed',
#   'share_link': 'https://www.google.com/search?ibp=htl;jobs&q=food+service+worker&htidocid=NTd1PEL-ovBNFbm_AAAAAA%3D%3D&hl=en-US&shndl=37&shmd=H4sIAAAAAAAA_xXHsQrCMBAAUFz7CU4HbqKNCA7aqYsFFwsWHEuaXpNozJW7KP0Z_9W6PHjZd5Edz0Q93JA_3iDciZ_IsIUKia3X0KBxcy_UgaDmORShIrIBl4VLaZSTUiIht5J08iY39FIUsaNJPaiTP604zTgGnbDdH3ZTPka7XtVMNMB1gMYh1O--99GCj1CmoGPSG6jKH0NjruCgAAAA&shmds=v1_AQbUm95lEeFi-Giyxsv6IUTKyZZ3rK-WaK4mAFYdeDqtaj-ztQ&shem=xcxes&source=sh/x/job/li/m1/1#fpstate=tldetail&htivrt=jobs&htiq=food+service+worker&htidocid=NTd1PEL-ovBNFbm_AAAAAA%3D%3D',
#   'thumbnail': 'https://serpapi.com/searches/67d98be802983538ab1b00d0/images/8673a881b65dd3bbe33dc955c7bb25cac9cfbde83d8130af651bf86b97fd3434.jpeg',
#   'extensions': ['17 an hour',
#    'Part-time',
#    'No degree mentioned',
#    'Health insurance'],
#   'detected_extensions': {'salary': '17 an hour',
#    'schedule_type': 'Part-time',
#    'qualifications': 'No degree mentioned',
#    'health_insurance': True},
#   'description': 'Proof of the Pudding is an award-winning catering company throughout the Southeast with a commitment to creating quality culinary concepts from scratch. This standard was upheld through the expansion into Sports and Entertainment Hospitality Services by providing elevated concessions and premium offerings to collegiate stadiums, PGA golf tournaments, International Boat Shows, Professional Sports Teams, & more.\n\nWe are currently seeking experienced Food Service Workers to join the team at Georgia Tech. POP provides daily food service to GTs student athletes via the Training Table and provides F&B for other athletic events. This position will work with the front of house team and be in and out of kitchens.\n\nThis is seasonal/part-time work as business needs are dictated by athletic events.\n\nESSENTIAL DUTIES AND RESPONSIBILITIES\n• Assist in setting food stations which will include transporting hot and cold food itemsthrough out the service area\n• Replenishing food items as needed and directed\n• Operate and provide service at an interactive station i.e. build your own smoothie\n• Serve and clear food and beverage quietly, professionally, and quickly, using proper serving and clearing techniques.\n• Keep work area clean, and coordinate actions with the FOH Supervisor to ensure flawless customer service.\n• Managing time effectively.\n• Assist in managing inventory of equipment and with set up and breakdown of events.\n• Reporting to the FOH Supervisor and performing any tasks assigned in order to execute a flawless event.\n• Follow proper food handing sanitation guidelines.\n• Assist in the clean up and flip of service area in preparation for the next service time.\n\nPerforms other related duties as required.\n\nEducation and/or Experience:\n• 1+ year of Serving and/or Front of House experience.\n• Experience in high volume catering or food service is preferred.\n\nSpecialized Qualifications:\n• Excellent listening and communication skills\n• Renowned time management and organization skills\n• Strong Customer Service skills with the desire to go above and beyond a clients needs.\n• The ability to work alone and as a team.\n• Strong attention to detail and the ability to learn and adapt quickly.\n• Must be exceedingly responsible and accountable.\n\nWork Environment\n\nThe work environment for this position will mainly attend to the Student Athlete Training Table located in Bobby Dodd Field. This position will move in and out of the kitchen and food service area including but not limited to coolers, freezers, and other sanitary places. This position may also move throughout campus and stadium grounds on different terrains.\n\nUniform Requirements\n\nAdherence to Company Uniform Requirements outlined in the Associate Handbook, uniform requirements outlined in your orientation guidelines.\n\nPhysical Demands:\n• Prolonged periods of standing, moving through an event space, and traveling from venue to venue\n• Bending, lifting, scooping, and carrying miscellaneous equipment and food items\n• Ability to perform physical tasks; such as but not limited to, lifting approx. 30 lbs.\n\nCORE VALUE AND COMPETENCY REQUIREMENTS\n• Business Acumen - Demonstrate comprehension of the job, including policies, practices, and relationships. Possess the expertise and skill levels required of the job and perform with quality.\n• Dedication - Dependable, reliable and follows through on projects from inception to completion. Willing to put in as much time as necessary to complete tasks. Demonstrate a win-win attitude: see it, own it, solve it.\n• Ethics and Integrity - Acts with integrity, honesty and knowledge that promote the companys culture, values and beliefs while maintaining the highest standards of professional conduct.\n• Safety & Security - Observe safety and security standards. Use equipment and materials properly. Comply with safety standards and personal protective equipment requirements. Report potential unsafe con ...
#   'job_highlights': [{'title': 'Qualifications',
#     'items': ['1+ year of Serving and/or Front of House experience',
#      'Excellent listening and communication skills',
#      'Renowned time management and organization skills',
#      'Strong Customer Service skills with the desire to go above and beyond a clients needs',
#      'The ability to work alone and as a team',
#      'Strong attention to detail and the ability to learn and adapt quickly',
#      'Must be exceedingly responsible and accountable',
#      'Adherence to Company Uniform Requirements outlined in the Associate Handbook, uniform requirements outlined in your orientation guidelines',
#      'Ability to perform physical tasks; such as but not limited to, lifting approx',
#      '30 lbs',
#      'CORE VALUE AND COMPETENCY REQUIREMENTS',
#      'Business Acumen - Demonstrate comprehension of the job, including policies, practices, and relationships',
#      'Possess the expertise and skill levels required of the job and perform with quality',
#      'Dedication - Dependable, reliable and follows through on projects from inception to completion',
#      'Willing to put in as much time as necessary to complete tasks',
#      'Communication - Communicate clearly and effectively with mutual respect, understanding and trust to fellow associates, managers, supervisors and guests',
#      'Listen carefully to opinions and views of others; state understanding of what has been heard',
#      'Initiative - Contribute new ideas and suggestions to enhance productivity and efficiency',
#      'Perform well under tight time schedules and pressures to change direction quickly',
#      'Is welcoming, friendly and smiles when visible to guests']},
#    {'title': 'Benefits',
#     'items': ['This is considered a part-time hourly position',
#      'The schedule for this position may range depending on business needs but will often consist of either a morning shift covering breakfast operations or a later shift covering dinner service',
#      'Other benefits include free meals and ample career advancement opportunities',
#      'On-the-job training that can be applied industry wide']},
#    {'title': 'Responsibilities',
#     'items': ['This position will work with the front of house team and be in and out of kitchens',
#      'This is seasonal/part-time work as business needs are dictated by athletic events',
#      'Assist in setting food stations which will include transporting hot and cold food itemsthrough out the service area',
#      'Replenishing food items as needed and directed',
#      'Operate and provide service at an interactive station i.e. build your own smoothie',
#      'Serve and clear food and beverage quietly, professionally, and quickly, using proper serving and clearing techniques',
#      'Keep work area clean, and coordinate actions with the FOH Supervisor to ensure flawless customer service',
#      'Managing time effectively',
#      'Assist in managing inventory of equipment and with set up and breakdown of events',
#      'Reporting to the FOH Supervisor and performing any tasks assigned in order to execute a flawless event',
#      'Follow proper food handing sanitation guidelines',
#      'Assist in the clean up and flip of service area in preparation for the next service time',
#      'Performs other related duties as required',
#      'The work environment for this position will mainly attend to the Student Athlete Training Table located in Bobby Dodd Field',
#      'This position will move in and out of the kitchen and food service area including but not limited to coolers, freezers, and other sanitary places',
#      'This position may also move throughout campus and stadium grounds on different terrains',
#      'Prolonged periods of standing, moving through an event space, and traveling from venue to venue',
#      'Bending, lifting, scooping, and carrying miscellaneous equipment and food items',
#      'Demonstrate a win-win attitude: see it, own it, solve it',
#      'Ethics and Integrity - Acts with integrity, honesty and knowledge that promote the companys culture, values and beliefs while maintaining the highest standards of professional conduct',
#      'Safety & Security - Observe safety and security standards',
#      'Use equipment and materials properly',
#      'Comply with safety standards and personal protective equipment requirements',
#      'Report potential unsafe conditions or practices to appropriate person immediately',
#      'Promote restaurant safety, cleanliness and security compliance at all times',
#      'Teamwork - Cooperate and be willing to work as a team player to achieve goals and tasks accurately, efficiently and timely',
#      'Be proactive in troubleshooting problems or issues and take action to mitigate potential problems',
#      'Adaptability & Planning - Possess the ability to learn new tasks and adjusts well to new situations',
#      'Service Orientation - Demonstrates a sense of urgency']}],
#   'apply_options': [{'title': 'Indeed',
#     'link': 'https://www.indeed.com/viewjob?jk=56834209adf92265&utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic'},
#    {'title': 'ZipRecruiter',
#     'link': 'https://www.ziprecruiter.com/c/Work-For-Warriors-Georgia/Job/Food-Service-Worker-Oglethorpe-University/-in-Atlanta,GA?jid=9bc798c46ab62d18&utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic'},
#    {'title': 'Glassdoor',
#     'link': 'https://www.glassdoor.com/job-listing/food-service-worker-part-time-metro-rydc-atlanta-ga-ccr-state-of-georgia-JV_IC1155583_KO0,55_KE56,72.htm?jl=1009601706119&utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic'},
#    {'title': 'LinkedIn',
#     'link': 'https://www.linkedin.com/jobs/view/food-service-worker-georgia-tech-at-proof-of-the-pudding-3978669809?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic'},
#    {'title': 'SimplyHired',
#     'link': 'https://www.simplyhired.com/job/Pz8oQN9fEzIeelv3LEdR-22tQAZg__TovL8As7YpOHFpN1oAHDYsaQ?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic'},
#    {'title': 'Adzuna',
#     'link': 'https://www.adzuna.com/details/4816947886?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic'},
#    {'title': 'EarnBetter',
#     'link': 'https://earnbetter.com/app/job/01JM1B7EZAD9SPX7SJQRWK2FN7/?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic'},
#    {'title': 'Talentify',
#     'link': 'https://www.talentify.io/job/food-service-worker-georgia-tech-atlanta-georgia-proof-of-the-pudding-64594?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic'}],
#   'job_id': ''},
#  {'title': 'Food Service Worker',
#   'company_name': 'Aramark',
#   'location': 'Atlanta, GA',
#   'via': 'Aramark Careers',
#   'share_link': 'https://www.google.com/search?ibp=htl;jobs&q=food+service+worker&htidocid=bVTTyL77XuWD123FAAAAAA%3D%3D&hl=en-US&shndl=37&shmd=H4sIAAAAAAAA_xXEsQrCMBAAUFz7AQ5ONxdNRHDRqYsFVwfHcolHUpvmyt0hXf1z8Q2v-W6a9sb8ggfJZ4wET5aJBA5w5wBKKDEDV-iZU6HdNZstevFetbikhjZGF3n2XCnw6t8c9N-gGYWWgkbD6Xxc3VJTu-0EZ5QJxgqdFayGe-i7H6DCQ2yEAAAA&shmds=v1_AQbUm94jwiFXRuAuK_CBzM2RyDRLV5d_6-szHRilpd7G1d7Qvw&shem=xcxes&source=sh/x/job/li/m1/1#fpstate=tldetail&htivrt=jobs&htiq=food+service+worker&htidocid=bVTTyL77XuWD123FAAAAAA%3D%3D',
#   'extensions': ['15 days ago', 'Full-time', 'No degree mentioned'],
#   'detected_extensions': {'posted_at': '15 days ago',
#    'schedule_type': 'Full-time',
#    'qualifications': 'No degree mentioned'},
#   'description': "Job Description\n\nThe Food Service Worker at Metro - Georgia Department of Corrections supervises inmates to ensure that meal and food items are prepared in accordance with production plans. In this role, you will train workers in methods of performing duties, as well as assign and coordinate work to promote the efficiency of operations. This person is also responsible for the sanitation of the facility and maintaining personal safety, by conforming to all standards and regulations. Essential functions and responsibilities of the position may vary by Aramark location based on client requirements and business needs.\n\nJob Responsibilities\n\n• Adhere to and maintain preparation and production guidelines according to Aramark standards by reviewing and approving production and temperature logs.\n\n• Supervise inmates in food preparation and tray assembly.\n\n• Ensure timely, efficient meal service and all Aramark guidelines are being met.\n\n• Participate in preparation and serving of meals\n\n• Prints and distribute recipes.\n\n• Direct inmates in the use of Aramark recipes and train on proper cooking procedures.\n\n• Ensure proper portions and any special dietary requirements are fulfilled.\n\n• Obtain accurate daily population counts and review with staff.\n\n• Adhere to security policies and procedures. Ensure storage areas are locked at all times.\n\n• Ensure that all kitchen tools and equipment are returned to their designated secure area. Ensure all keys are returned and secured.\n\n• Determines work procedures, prepares work schedules and sanitation schedules while ensuring that cooks, inmates and/or food service workers adhere to the assigned schedule.\n\n• Assist in conducting inventory, properly receiving, and storing food and food related items. Requisition orders as needed for approval.\n\n• Participates in the preparation/5 P’s (Participation, Pulls, Production, Portion Control, and Postproduction), storage and assembly of meals and food items.\n\n• Follows the Company’s Standard of Operation for food handling and storage. Follows HACCP policies and procedures regarding proper food handling procedures.\n\nAt Aramark, developing new skills and doing what it takes to get the job done make a positive impact for our employees and for our customers. In order to meet our commitments, job duties may change or new ones may be assigned without formal notice.\n\nQualifications\n\n• Must be over 18 years of age\n\n• Minimum of one (1) year of food prep or related work preferred\n\n• Previous supervisory experience preferred\n\n• Previous experience interacting with inmates a plus\n\n• Ability to motivate and supervise inmates and/or team members to attain quality and quantity of food production in a correctional work environment\n\n• Must be able to obtain a food safety certification\n\n• Ability to work independently with limited supervision\n\n• Ability to exercise good judgment and tact\n\n• Must be able to follow basic safety procedures and policies\n\n• Must qualify for and maintain correctional facility security clearance\n\nThis role may have physical demands including, but not limited to, lifting, bending, pushing, pulling and/or extended walking and standing. This role may also require uniforms and/or usage of Personal Protective Equipment (PPE).\n\nEducation\n\nAbout Aramark\n\nOur Mission\n\nRooted in service and united by our purpose, we strive to do great things for each other, our partners, our communities, and our planet.\n\nAt Aramark, we believe that every employee should enjoy equal employment opportunity and be free to participate in all aspects of the company. We do not discriminate on the basis of race, color, religion, national origin, age, sex, gender, pregnancy, disability, sexual orientation, gender identity, genetic information, military status, protected veteran status or other characteristics protected by applicable law.\n\nAbout Aramark\n\nThe people of Aramark proudly serve mil ...
#   'job_highlights': [{'title': 'Qualifications',
#     'items': ['Must be over 18 years of age',
#      'Ability to motivate and supervise inmates and/or team members to attain quality and quantity of food production in a correctional work environment',
#      'Must be able to obtain a food safety certification',
#      'Ability to work independently with limited supervision',
#      'Ability to exercise good judgment and tact',
#      'Must be able to follow basic safety procedures and policies',
#      'Must qualify for and maintain correctional facility security clearance',
#      'This role may also require uniforms and/or usage of Personal Protective Equipment (PPE)']},
#    {'title': 'Responsibilities',
#     'items': ['The Food Service Worker at Metro - Georgia Department of Corrections supervises inmates to ensure that meal and food items are prepared in accordance with production plans',
#      'In this role, you will train workers in methods of performing duties, as well as assign and coordinate work to promote the efficiency of operations',
#      'This person is also responsible for the sanitation of the facility and maintaining personal safety, by conforming to all standards and regulations',
#      'Essential functions and responsibilities of the position may vary by Aramark location based on client requirements and business needs',
#      'Adhere to and maintain preparation and production guidelines according to Aramark standards by reviewing and approving production and temperature logs',
#      'Supervise inmates in food preparation and tray assembly',
#      'Ensure timely, efficient meal service and all Aramark guidelines are being met',
#      'Participate in preparation and serving of meals',
#      'Prints and distribute recipes',
#      'Direct inmates in the use of Aramark recipes and train on proper cooking procedures',
#      'Ensure proper portions and any special dietary requirements are fulfilled',
#      'Obtain accurate daily population counts and review with staff',
#      'Adhere to security policies and procedures',
#      'Ensure storage areas are locked at all times',
#      'Ensure that all kitchen tools and equipment are returned to their designated secure area',
#      'Ensure all keys are returned and secured',
#      'Determines work procedures, prepares work schedules and sanitation schedules while ensuring that cooks, inmates and/or food service workers adhere to the assigned schedule',
#      'Assist in conducting inventory, properly receiving, and storing food and food related items',
#      'Requisition orders as needed for approval',
#      'Participates in the preparation/5 P’s (Participation, Pulls, Production, Portion Control, and Postproduction), storage and assembly of meals and food items',
#      'Follows the Company’s Standard of Operation for food handling and storage',
#      'Follows HACCP policies and procedures regarding proper food handling procedures',
#      'This role may have physical demands including, but not limited to, lifting, bending, pushing, pulling and/or extended walking and standing']}],
#   'apply_options': [{'title': 'Aramark Careers',
#     'link': 'https://aramarkcareers.com/UnitedStates/job/Atlanta-Food-Service-Worker-GA-30316/1269136300/?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic'},
#    {'title': 'Sodexo Jobs',
#     'link': 'https://jobs.us.sodexo.com/food-service-worker/job/28893852?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic'},
#    {'title': 'Indeed',
#     'link': 'https://www.indeed.com/viewjob?jk=8efcd295d9192c16&utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic'},
#    {'title': 'ZipRecruiter',
#     'link': 'https://www.ziprecruiter.com/c/Sodexo/Job/Food-Service-Worker/-in-Atlanta,GA?jid=0c73dcc2a221e0a6&utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic'},
#    {'title': 'Glassdoor',
#     'link': 'https://www.glassdoor.com/job-listing/food-service-worker-ssp-JV_IC1155583_KO0,19_KE20,23.htm?jl=1009633974644&utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic'},
#    {'title': 'Sodexo.paradox.ai',
#     'link': 'https://sodexo.paradox.ai/co/Sodexo1/Job?job_id=P27-1557110-2&utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic'},
#    {'title': 'LocalJobs.com',
#     'link': 'https://www.localjobs.com/job/atlanta-ga-corrections-oversight-worker-metro-ga-doc?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic'},
#    {'title': 'LinkedIn',
#     'link': 'https://www.linkedin.com/jobs/view/food-service-worker-at-sodexo-4146185786?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic'}],
#   'job_id': 'eyJqb2JfdGl0bGUiOiJGb29kIFNlcnZpY2UgV29ya2VyIiwiY29tcGFueV9uYW1lIjoiQXJhbWFyayIsImFkZHJlc3NfY2l0eSI6IkF0bGFudGEsIEdBIiwiaHRpZG9jaWQiOiJiVlRUeUw3N1h1V0QxMjNGQUFBQUFBPT0iLCJ1dWxlIjoidytDQUlRSUNJWVFYUnNZVzUwWVN4SFFTeFZibWwwWldRZ1UzUmhkR1Z6IiwiaGwiOiJlbiJ9'},
#  {'title': 'FOOD SERVICE UTILITY (SEASONAL)',
#   'company_name': 'Compass Group',
#   'location': 'Atlanta, GA',
#   'via': 'Compass Group',
#   'share_link': 'https://www.google.com/search?ibp=htl;jobs&q=food+service+worker&htidocid=Ldu2_M43W5g8ySsaAAAAAA%3D%3D&hl=en-US&shndl=37&shmd=H4sIAAAAAAAA_xXEwQqCQBAAULr6CdFhjhXlRlCHOi1mYkhCWtBJRlnUWHcWZ4L-ox-O3uEF30mwP-f5CYr49kijGO5lmqXlE-ZFrIv8qrMFrOFCNbDBsemAHCRErTXTYyfi-aAUsw1bFpS-CRsaFDlT00e9qOZ_FXc4Gm9RTLXdbT6hd-1yFtHgkRmSkd4eegdaLDrBFST6B2y_NySWAAAA&shmds=v1_AQbUm96lE2vIo3-NXWVGSEOLPlFBpqO20qn8u2GUKu3Nuoe3qA&shem=xcxes&source=sh/x/job/li/m1/1#fpstate=tldetail&htivrt=jobs&htiq=food+service+worker&htidocid=Ldu2_M43W5g8ySsaAAAAAA%3D%3D',
#   'extensions': ['2 days ago',
#    'No degree mentioned',
#    'Paid time off',
#    'Health insurance'],
#   'detected_extensions': {'posted_at': '2 days ago',
#    'qualifications': 'No degree mentioned',
#    'paid_time_off': True,
#    'health_insurance': True},
#   'description': "• We have an opening for seasonal FOOD SERVICE UTILITY positions.\n• Location: Georgia Aquarium - 225 Baker Street, Atlanta, GA 30313. Note: online applications accepted only.\n• Schedule: Seasonal schedule, as needed: Days and hours may vary. Nights, weekends, and holidays required. More details upon interview.\n• Requirement: No prior experience required.\n• Pay Range: $16.00 per hour to $17.00 per hour.\n\nWe Make Applying Easy! Want to apply to this job via text messaging? Text JOB to 75000 and search requisition ID number 1408061.\n\nThe advertised program is a conversational recruiting assistant that helps you apply to jobs with Compass Group. Message frequency varies. Message and data rates may apply. Text STOP to opt out or HELP for help. Terms and conditions: http://olivia.paradox.ai/moSkg\n\nThis position is eligible for an Employee Referral Bonus! If you know someone that would be a great fit for this role, you can refer them to this position and potentially earn an Employee Referral Bonus! Click here to view the step-by-step instructions to refer a friend to this position.\n\nBecome part of Restaurant Associates, the industry’s leading provider of dining and event catering for some of the nation's most prestigious museums, performing arts centers and corporations! Voted Glassdoor's Employee Choice Awards- Best Places to work This is R/A !\n\n\u200b\n\nJob Summary\n\nSummary: Maintains kitchen work areas, and keeps equipment and utensils clean and orderly.\n\nEssential Duties and Responsibilities:\n• Sweeps and mops floors to comply with safety and sanitation standards.\n• Washes worktables, walls, refrigerators, meat blocks and other food prep surfaces.\n• Removes trash and places it into designated containers. Steam cleans or hoses out garbage cans.\n• Transfers supplies and equipment between storage and work areas.\n• Assists with banquet table and front of the house set up.\n• Assist with loading or unloading and delivering supplies and product.\n• Distributes supplies, utensils and portable equipment as needed.\n• Complies with outlined sanitation and safety requirements.\n• Performs other duties as assigned.\n\nAssociates at Restaurant Associates are offered many fantastic benefits.\n\nBoth full-time and part-time positions offer the following benefits to associates:\n• Retirement Plan\n• Associate Shopping Program\n• Health and Wellness Programs\n• Discount Marketplace\n• Identity Theft Protection\n• Pet Insurance\n• Voluntary Benefits, including Critical Illness Insurance, Accident Insurance, Hospital Indemnity Insurance, Legal Services, and Choice Auto and Home Program\n\nIn addition, full-time positions also offer the following benefits to associates:\n• Medical\n• Dental\n• Vision\n• Life Insurance/AD\n• Disability Insurance\n• Commuter Benefits\n• Employee Assistance Program\n• Flexible Spending Accounts (FSAs)\n\nAbides by all Company policies and procedures including but not limited to:\n• The use of a medium weight cut gloves when handling or using knives, peelers, choppers, mandolins or cleaning a slicer.\n• The use of oven mitts, fryer gloves or steamer gloves when handling hot pans from ovens, warmers or steamtables.\n• The use of slip-resistant shoes and proper lifting techniques.\n\nAssociates may also be eligible for paid and/or unpaid time off benefits in accordance with applicable federal, state, and local laws. For positions in Washington State, Maryland, or to be performed Remotely, click here for paid time off benefits information.\n\nAbout Compass Group: Achieving leadership in the foodservice industry\n\nCompass Group is an equal opportunity employer. At Compass, we are committed to treating all Applicants and Associates fairly based on their abilities, achievements, and experience without regard to race, national origin, sex, age, disability, veteran status, sexual orientation, gender identity, or any other classification protected by law.\n\nQualified candidates must b ...
#   'job_highlights': [{'title': 'Qualifications',
#     'items': ['Requirement: No prior experience required',
#      'Qualified candidates must be able to perform the essential functions of this position satisfactorily with or without a reasonable accommodation']},
#    {'title': 'Benefits',
#     'items': ['Pay Range: $16.00 per hour to $17.00 per hour',
#      'Both full-time and part-time positions offer the following benefits to associates:',
#      'Retirement Plan',
#      'Associate Shopping Program',
#      'Health and Wellness Programs',
#      'Discount Marketplace',
#      'Identity Theft Protection',
#      'Pet Insurance',
#      'Voluntary Benefits, including Critical Illness Insurance, Accident Insurance, Hospital Indemnity Insurance, Legal Services, and Choice Auto and Home Program',
#      'In addition, full-time positions also offer the following benefits to associates:',
#      'Medical',
#      'Dental',
#      'Vision',
#      'Life Insurance/AD',
#      'Disability Insurance',
#      'Commuter Benefits',
#      'Employee Assistance Program',
#      'Flexible Spending Accounts (FSAs)',
#      'Associates may also be eligible for paid and/or unpaid time off benefits in accordance with applicable federal, state, and local laws']},
#    {'title': 'Responsibilities',
#     'items': ['Schedule: Seasonal schedule, as needed: Days and hours may vary',
#      'Nights, weekends, and holidays required',
#      "Become part of Restaurant Associates, the industry’s leading provider of dining and event catering for some of the nation's most prestigious museums, performing arts centers and corporations!",
#      'Summary: Maintains kitchen work areas, and keeps equipment and utensils clean and orderly',
#      'Sweeps and mops floors to comply with safety and sanitation standards',
#      'Washes worktables, walls, refrigerators, meat blocks and other food prep surfaces',
#      'Removes trash and places it into designated containers',
#      'Steam cleans or hoses out garbage cans',
#      'Transfers supplies and equipment between storage and work areas',
#      'Assists with banquet table and front of the house set up',
#      'Assist with loading or unloading and delivering supplies and product',
#      'Distributes supplies, utensils and portable equipment as needed',
#      'Complies with outlined sanitation and safety requirements',
#      'Performs other duties as assigned',
#      'The use of a medium weight cut gloves when handling or using knives, peelers, choppers, mandolins or cleaning a slicer',
#      'The use of oven mitts, fryer gloves or steamer gloves when handling hot pans from ovens, warmers or steamtables',
#      'The use of slip-resistant shoes and proper lifting techniques']}],
#   'apply_options': [{'title': 'Compass Group',
#     'link': 'https://jobs.compassgroupcareers.com/United_States/job/ATLANTA-FOOD-SERVICE-UTILITY-%28SEASONAL%29-GA-30313/1273410300/?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic'},
#    {'title': 
source=sh/x/job/li/m1/1#fpstate=tldetail&htivrt=jobs&htiq=food+service+worker&htidocid=FEapT6jo4AVwmHx3AAAAAA%3D%3D',
#   'extensions': ['3 days ago', 'Full-time', 'No degree mentioned'],
#   'detected_extensions': {'posted_at': '3 days ago',
#    'schedule_type': 'Full-time',
#    'qualifications': 'No degree mentioned'},
#   'description': "Job Description\n\nThe Food Service Worker will assist the manager with food/meal preparation; maintain cash receipts and meal records. Assist manager in completing daily reports. Maintain high standards of quality in food production, sanitation, and kitchen safety practices.\n\nJob Responsibilities\n• Prepare quality food and baked goods according to a planned menu\n• Prepare a daily report that verifies transactions\n• Understand what is inclusive of a meal\n• Ensure storage of food in an accurate and sanitary manner\n• Serve food according to meal schedules, department policies and procedures\n• Use and care of kitchen equipment, especially knives\n• Timely preparation of a variety of food items, beverages, and\n• Add garnishments to ensure customer happiness and eye appeal\n• Coordinate and assist in major cleaning of refrigerators, freezers, and cooking and serving equipment\n• Adhere to all food safety regulations for sanitation, food handling, and storage\n• Adhere to the uniform policy\n• Connect with the Manager daily to understand and accurately prepare menu for the day\n• Supervise the food temperature requirements\n• Maintain a clean and organized work and storage area\n• Scrub and polish counters, clean and sanitize steam tables, and other equipment\n• Follow established procedures and standards for cleanliness, to ensure a balanced and safe environment; duties include sweeping, moping, ware washing\n• Maintain garbage collection site and kitchen floor areas in a neat and sanitary fashion\n• Perform other duties as assigned including other areas in the kitchen\n• This role may have physical demands including, but not limited to, lifting, bending, pushing, pulling and/or extended walking and standing. This role may also require uniforms and/or usage of Personal Protective Equipment (PPE).\n\nAt Aramark, developing new skills and doing what it takes to get the job done make a positive impact for our employees and for our customers. In order to meet our commitments, job duties may change or new ones may be assigned without formal notice.\n\nQualifications\n• Food Service Certificate as needed\n• Sufficient education or training to read, write, and follow verbal and written instructions\n• Be able to work quickly and concisely under pressure\n\nEducation\n\nAbout Aramark\n\nOur Mission\n\nRooted in service and united by our purpose, we strive to do great things for each other, our partners, our communities, and our planet.\n\nAt Aramark, we believe that every employee should enjoy equal employment opportunity and be free to participate in all aspects of the company. We do not discriminate on the basis of race, color, religion, national origin, age, sex, gender, pregnancy, disability, sexual orientation, gender identity, genetic information, military status, protected veteran status or other characteristics protected by applicable law.\n\nAbout Aramark\n\nThe people of Aramark proudly serve millions of guests every day through food and facilities in 15 countries around the world. Rooted in service and united by our purpose, we strive to do great things for each other, our partners, our communities, and our planet. We believe a career should develop your talents, fuel your passions, and empower your professional growth. So, no matter what you're pursuing - a new challenge, a sense of belonging, or just a great place to work - our focus is helping you reach your full potential. Learn more about working here at http://www.aramarkcareers.com or connect with us on Facebook, Instagram and Twitter.",
#   'job_highlights': [{'title': 'Qualifications',
#     'items': ['This role may also require uniforms and/or usage of Personal Protective Equipment (PPE)',
#      'Food Service Certificate as needed',
#      'Sufficient education or training to read, write, and follow verbal and written instructions',
#      'Be able to work quickly and concisely under pressure']},
#    {'title': 'Responsibilities',
#     'items': ['The Food Service Worker will assist the manager with food/meal preparation; maintain cash receipts and meal records',
#      'Assist manager in completing daily reports',
#      'Maintain high standards of quality in food production, sanitation, and kitchen safety practices',
#      'Prepare quality food and baked goods according to a planned menu',
#      'Prepare a daily report that verifies transactions',
#      'Understand what is inclusive of a meal',
#      'Ensure storage of food in an accurate and sanitary manner',
#      'Serve food according to meal schedules, department policies and procedures',
#      'Use and care of kitchen equipment, especially knives',
#      'Timely preparation of a variety of food items, beverages, and',
#      'Add garnishments to ensure customer happiness and eye appeal',
#      'Coordinate and assist in major cleaning of refrigerators, freezers, and cooking and serving equipment',
#      'Adhere to all food safety regulations for sanitation, food handling, and storage',
#      'Adhere to the uniform policy',
#      'Connect with the Manager daily to understand and accurately prepare menu for the day',
#      'Supervise the food temperature requirements',
#      'Maintain a clean and organized work and storage area',
#      'Scrub and polish counters, clean and sanitize steam tables, and other equipment',
#      'Follow established procedures and standards for cleanliness, to ensure a balanced and safe environment; duties include sweeping, moping, ware washing',
#      'Maintain garbage collection site and kitchen floor areas in a neat and sanitary fashion',
#      'Perform other duties as assigned including other areas in the kitchen',
#      'This role may have physical demands including, but not limited to, lifting, bending, pushing, pulling and/or extended walking and standing']}],
#   'apply_options': [{'title': 'Aramark Careers',
#     'link': 'https://aramarkcareers.com/UnitedStates/job/Atlanta-Food-Service-Worker-Dining-Services-at-Oglethorpe-University-GA-30319/1263035800/?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic'},
#    {'title': 'ZipRecruiter',
#     'link': 'https://www.ziprecruiter.com/c/Aramark/Job/Food-Service-Worker-Dining-Services-at-Oglethorpe-University/-in-Atlanta,GA?jid=208d64ff56fce70a&utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic'},
#    {'title': 'The Muse',
#     'link': 'https://www.themuse.com/jobs/aramark/food-service-worker-dining-services-at-oglethorpe-university-7d0e53?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic'},
#    {'title': 'LocalJobs.com',
#     'link': 'https://www.localjobs.com/job/atlanta-ga-general-utility-worker-dining-services-oglethorpe-university-0?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic'},
#    {'title': 'Indeed',
#     'link': 'https://www.indeed.com/viewjob?jk=b9f99071e317a736&utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic'},
#    {'title': 'LinkedIn',
#     'link': 'https://www.linkedin.com/jobs/view/general-utility-worker-dining-services-at-oglethorpe-university-at-aramark-4156200588?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic'},
#    {'title': 'Jooble',
#     'link': 'https://jooble.org/jdp/-4199932355425184376?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic'},
#    {'title': 'SimplyHired',
#     'link': 'https://www.simplyhired.com/job/CNqjD0MnrOtFk_V-Clpseb8dTv3zG9tIvUuSxf-Yn2A2zuep5FZSkQ?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic'}],
#   'job_id': ''},
#  {'title': 'Cafe Food Service Worker',
#   'company_name': 'SLA MANAGEMENT INC',
#   'location': 'Atlanta, GA',
#   'via': 'Indeed',
#   'share_link': 'https://www.google.com/search?ibp=htl;jobs&q=food+service+worker&htidocid=dTFKPpILIOdw2vbyAAAAAA%3D%3D&hl=en-US&shndl=37&shmd=H4sIAAAAAAAA_xXEwQqCQBAAULr6CZ2ma5QbQZc6LWJSpBeDjjJuk1rbjuwM4W_0x9E7vOQ7S0yGD4Ij8x1qip_BEdw4vijCGs7cghBG1wMHKJg7T_NDrzrK3hgRn3aiqINLHb8NB2p5Mk9u5V8jPUYaPSo1291mSsfQLRf1xUJpK1vkZV5d4VRlMASw6jEorqCwP4fymgCUAAAA&shmds=v1_AQbUm95LknDcpNfnUKKg4VX1sWub33F0TG-TL_J8WxVih_HPtA&shem=xcxes&source=sh/x/job/li/m1/1#fpstate=tldetail&htivrt=jobs&htiq=food+service+worker&htidocid=dTFKPpILIOdw2vbyAAAAAA%3D%3D',
#   'extensions': ['19 days ago', 'Full-time', 'No degree mentioned'],
#   'detected_extensions': {'posted_at': '19 days ago',
#    'schedule_type': 'Full-time',
#    'qualifications': 'No degree mentioned'},
#   'description': 'Become a HERO and Never Work Weekends again!\n\nWe are looking for a School Cafeteria Food Service Worker who is responsible for ensuring and maintaining regular daily operations of the designated location.\n\nAbout the Job\n\nSLA Management a company with over 20 years of experience providing customized meal programs to charter and private school cafeterias across the nation is actively hiring for the current and future School Years.\n\nEssential Duties and Responsibilities\n• Complete other duties or administrative request requests as assigned by the Leaders of SLA.\n• Ensuring their daily tasks are completed in compliance and following all standard operational procedures.\n• Making sure all food and sanitation standards are up to standards.\n• Ensure the use of proper techniques for maintenance of cleanliness and preparation of food and kitchen.\n• Participate in the preparation, cooking, and serving of menu items.\n• Ensure accurate payment information and cash flow.\n• Make sure all prep work is completed accurately and timely.\n\nQUALIFICATIONS, EDUCATION, EXPERIENCE, KNOWLEDGE AND SKILLS\n• Strong work ethic and team player\n• Ability to communicate with various levels of management.\n• Organizational, multi-tasking, and prioritizing skills.\n• Experience with POS and online reporting systems is also strongly preferred.\n• Preferred food service experience\n• Basic math a computer skill\n• Reliable transportation required.\n• Customer-focused\n• Enjoys working with people and being around children.\n• Used to repetitive routine work.\n• Cashier experience is a plus.\n\nSLA Management is an Equal Opportunity Employer. We do not discriminate based on race, color, religion, sex (including pregnancy), sexual orientation, gender identity, national origin, age, disability, genetic information, or veteran status. All employment is decided based on qualifications, merit, and business needs.',
#   'job_highlights': [{'title': 'Qualifications',
#     'items': ['QUALIFICATIONS, EDUCATION, EXPERIENCE, KNOWLEDGE AND SKILLS',
#      'Strong work ethic and team player',
#      'Ability to communicate with various levels of management',
#      'Organizational, multi-tasking, and prioritizing skills',
#      'Basic math a computer skill',
#      'Reliable transportation required',
#      'Customer-focused',
#      'Enjoys working with people and being around children',
#      'Used to repetitive routine work']},
#    {'title': 'Responsibilities',
#     'items': ['Complete other duties or administrative request requests as assigned by the Leaders of SLA',
#      'Ensuring their daily tasks are completed in compliance and following all standard operational procedures',
#      'Making sure all food and sanitation standards are up to standards',
#      'Ensure the use of proper techniques for maintenance of cleanliness and preparation of food and kitchen',
#      'Participate in the preparation, cooking, and serving of menu items',
#      'Ensure accurate payment information and cash flow',
#      'Make sure all prep work is completed accurately and timely']}],
#   'apply_options': [{'title': 'Indeed',
#     'link': 'https://www.indeed.com/viewjob?jk=4cbd7931c918bb62&utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic'},
#    {'title': 'ZipRecruiter',
#     'link': 'https://www.ziprecruiter.com/c/SLA-MANAGEMENT-INC/Job/Cafe-Food-Service-Worker/-in-Atlanta,GA?jid=bb80f6af57158234&utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic'},
#    {'title': 'LinkedIn',
#     'link': 'https://www.linkedin.com/jobs/view/cafe-food-service-worker-at-sla-management-inc-4170145838?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic'},
#    {'title': 'OysterLink',
#     'link': 'https://oysterlink.com/jobs/cafe-food-service-worker/?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic'}],
#   'job_id': ''}]

# %%
# Out:
# list

# %%
def get_process_str(highlights):
    desc = ''
    for info in highlights:
        if 'items' in info:
            desc += info['title'] + ': ' + '\n'.join(info['items']) + '\n\n'
    return desc

# %%
v = get_process_str(jobs_results[0]['job_highlights'])

# %%
print(v)
# Out:
# Qualifications: Ability to read and follow recipes
# Manual dexterity necessary to operate food preparation equipment and perform necessary cleaning
# Ability to understand and follow directions
# Good communication and interpersonal skills
# Ability to lift and carry a minimum of 50 pounds
# Ability to lift with the use of a ladder in high places
# Must be able to properly lift heavy items from a stooping position
# Must be able to stand and/or move about kitchen for entire shift
#
# Responsibilities: Prepares, cooks, serves, and stores food in accordance with accepted institutional procedures and Health Department Requirements; Adheres to all meal accountability procedures including cashiering
# Prepares cooks, and serves food in accordance with accepted institutional and HACCP procedures
# Follows daily production schedules, including preparing recipes as written
# Cleans all utensils and equipment used, disposes of garbage and mops assigned floor areas
# Utilizes left-over food as directed by the manager and stores all food items properly
# Utilizes and maintains equipment as trained
# Follows approved instructions for chemical use in the operation of the program
# Adheres to Federal, State, and Local policies, procedures, and regulations
# Adheres to Classified Employees Work Rules and School Nutrition Personnel and Uniform Standards
# Demonstrates ability to improve job-related skills and takes pride in serving students
# Completes 6 hours of in-service training yearly and attends all training as schedule through the School Nutrition Department
# Completes a 30-hour state required Orientation for Nutrition Employee course within the first year of employment
# Communicates effectively and promotes good public relations with students, teachers, and administrators
# Works with peers/supervisors in tactful, considerate, and cooperative manner and assists others when needed
# Performs other duties and responsibilities as assigned by the appropriate administrator
# Works in kitchen environment
# Works with hands in hot water and chemicals approved for use in the School Nutrition Program
# May involve exposure to extreme heat and cold
# Adheres to Fulton School Nutrition Personnel & Dress Standards
# Adheres to additional guidelines outlined in the employee handbook

# %%
# !pip install python-docx
# Out:
# Collecting python-docx
#   Downloading python_docx-1.1.2-py3-none-any.whl (244 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.3/244.3 kB 4.5 MB/s eta 0:00:00a 0:00:01
# Collecting lxml>=3.1.0
#   Downloading lxml-5.3.1-cp311-cp311-macosx_10_9_universal2.whl (8.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 10.4 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: typing-extensions>=4.9.0 in /Users/yasodasairamkandikonda/Desktop/Hack/venv/lib/python3.11/site-packages (from python-docx) (4.12.2)
# Installing collected packages: lxml, python-docx
# Successfully installed lxml-5.3.1 python-docx-1.1.2
#
# [notice] A new release of pip available: 22.3.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
from docx import Document
from docx.shared import Pt, RGBColor, Inches
from docx.enum.text import WD_PARAGRAPH_ALIGNMENT
from docx.oxml import OxmlElement
from docx.oxml.ns import qn

def add_heading_with_hr(doc, heading_text):
    """
    Adds a heading paragraph with a bottom border (horizontal rule)
    and minimal spacing after the heading.
    """
    p_heading = doc.add_paragraph()
    run = p_heading.add_run(heading_text)
    run.bold = True
    run.font.name = 'Calibri'
    run.font.size = Pt(10)
    p_heading.alignment = WD_PARAGRAPH_ALIGNMENT.LEFT
    p_heading.paragraph_format.space_after = Pt(2)

    # Add a bottom border to the heading (acts as a horizontal rule)
    pPr = p_heading._p.get_or_add_pPr()
    pBdr = OxmlElement('w:pBdr')
    bottom = OxmlElement('w:bottom')
    bottom.set(qn('w:val'), 'single')
    bottom.set(qn('w:sz'), '6')
    bottom.set(qn('w:space'), '1')
    bottom.set(qn('w:color'), 'auto')
    pBdr.append(bottom)
    pPr.append(pBdr)

def add_header(doc, user_details):
    """
    Adds a header with:
      - A big name (all caps, navy blue, size 16)
      - On the same line below, state, country and phone separated by a vertical bar.
    """
    header_para = doc.add_paragraph()
    # Candidate Name in all caps
    name_run = header_para.add_run(user_details.get('name', '').upper() + "\n")
    name_run.font.name = 'Calibri'
    name_run.font.size = Pt(16)
    name_run.font.color.rgb = RGBColor(0, 0, 128)  # navy blue
    name_run.bold = True

    # Contact info on the same line: state, country and phone
    details = f"{user_details.get('state', '')}, {user_details.get('country', '')} | {user_details.get('phone', '')}"
    details_run = header_para.add_run(details)
    details_run.font.name = 'Calibri'
    details_run.font.size = Pt(10)
    header_para.alignment = WD_PARAGRAPH_ALIGNMENT.CENTER

    # Add a horizontal rule after header (using a bottom border on an empty paragraph)
    hr_para = doc.add_paragraph()
    hr_para.paragraph_format.space_before = Pt(2)
    hr_para.paragraph_format.space_after = Pt(2)
    pPr = hr_para._p.get_or_add_pPr()
    pBdr = OxmlElement('w:pBdr')
    bottom = OxmlElement('w:bottom')
    bottom.set(qn('w:val'), 'single')
    bottom.set(qn('w:sz'), '6')
    bottom.set(qn('w:space'), '1')
    bottom.set(qn('w:color'), 'auto')
    pBdr.append(bottom)
    pPr.append(pBdr)

def set_right_tab_stop(paragraph, pos):
    """
    Adds a right-aligned tab stop at the given position (in twentieths of a point)
    to the paragraph. (e.g., pos=5000 is about 5 inches.)
    """
    pPr = paragraph._p.get_or_add_pPr()
    tabs = pPr.find(qn('w:tabs'))
    if tabs is None:
        tabs = OxmlElement('w:tabs')
        pPr.append(tabs)
    tab = OxmlElement('w:tab')
    tab.set(qn('w:val'), 'right')
    tab.set(qn('w:pos'), str(pos))
    tabs.append(tab)

def create_resume(user_details, output_file='resume.docx'):
    # Create a new Document
    doc = Document()
    
    # Set default font style for the document (Calibri, 10)
    style = doc.styles['Normal']
    style.font.name = 'Calibri'
    style.font.size = Pt(10)
    
    # Optionally reduce page margins
    for section in doc.sections:
        section.top_margin = Inches(0.5)
        section.bottom_margin = Inches(0.5)
        section.left_margin = Inches(0.5)
        section.right_margin = Inches(0.5)
    
    # Add header with name and contact info
    add_header(doc, user_details)
    
    # Helper to add a section with heading and minimal spacing after content
    def add_section(heading, content_func):
        add_heading_with_hr(doc, heading.upper())
        content_func()
        # Minimal spacing after section content
        para = doc.add_paragraph()
        para.paragraph_format.space_after = Pt(2)
    
    # Section: Summary
    def add_summary():
        p = doc.add_paragraph(user_details.get('summary', ''))
        p.paragraph_format.line_spacing = 1.0
        p.paragraph_format.space_after = Pt(2)
    
    # Section: Education (with duration on the right)
    def add_education():
        for edu in user_details.get('education', []):
            # Create a table with two columns:
            # Left: Education info, Right: Duration (right aligned)
            table = doc.add_table(rows=1, cols=2)
            table.autofit = True
            left_cell = table.rows[0].cells[0]
            right_cell = table.rows[0].cells[1]
            
            edu_text = f"{edu.get('degree', '')} in {edu.get('field', '')} - {edu.get('institution', '')}"
            left_cell.text = edu_text
            right_cell.text = f"{edu.get('start_date', '')} - {edu.get('end_date', '')}"
            for para in right_cell.paragraphs:
                para.alignment = WD_PARAGRAPH_ALIGNMENT.RIGHT
            # Minimal spacing after each education entry
            doc.add_paragraph().paragraph_format.space_after = Pt(2)
    
    # Section: Skills
    def add_skills():
        skills = user_details.get('skills', [])
        p_skills = doc.add_paragraph(', '.join(skills))
        p_skills.paragraph_format.line_spacing = 1.0
        p_skills.paragraph_format.space_after = Pt(2)
    
    # Section: Work Experience
    def add_work_experience():
        for exp in user_details.get('work_experience', []):
            # First line: Company name in bold
            p_company = doc.add_paragraph()
            run_company = p_company.add_run(exp.get('company', ''))
            run_company.bold = True
            run_company.font.name = 'Calibri'
            run_company.font.size = Pt(10)
            p_company.paragraph_format.space_after = Pt(0)
            
            # Next line: Job title (in italic) and duration on the same line
            p_job = doc.add_paragraph()
            # Set a right tab stop (position in twentieths of a point; adjust as needed)
            set_right_tab_stop(p_job, 5000)
            # Add job title (left-aligned)
            run_title = p_job.add_run(exp.get('role', ''))
            run_title.italic = True
            run_title.font.name = 'Calibri'
            run_title.font.size = Pt(10)
            # Insert a tab and then duration (which will be right-aligned due to the tab stop)
            run_duration = p_job.add_run("\t" + f"{exp.get('start_date', '')} - {exp.get('end_date', '')}")
            run_duration.font.name = 'Calibri'
            run_duration.font.size = Pt(10)
            
            # Add summary bullet points below
            summary = exp.get('summary', '')
            if isinstance(summary, list):
                for point in summary:
                    bullet = doc.add_paragraph(point, style='List Bullet')
                    bullet.paragraph_format.line_spacing = 1.0
                    bullet.paragraph_format.space_after = Pt(0)
            else:
                bullet = doc.add_paragraph(summary, style='List Bullet')
                bullet.paragraph_format.line_spacing = 1.0
                bullet.paragraph_format.space_after = Pt(0)
            
            # Minimal spacing after each work experience entry
            doc.add_paragraph().paragraph_format.space_after = Pt(2)
    
    # Add each section
    add_section('Summary', add_summary)
    add_section('Education', add_education)
    add_section('Skills', add_skills)
    add_section('Work Experience', add_work_experience)
    
    # Save the document
    doc.save(output_file)
    print(f"Resume saved as {output_file}")

if __name__ == '__main__':
    # Example user details
    user_details = {
        'name': 'John Doe',
        'state': 'California',
        'country': 'USA',
        'phone': '+1 234 567 890',
        'summary': 'Experienced software developer with a passion for building scalable applications. Skilled in multiple programming languages and frameworks.',
        'education': [
            {
                'degree': 'Bachelor of Science',
                'field': 'Computer Science',
                'institution': 'University A',
                'start_date': '2010',
                'end_date': '2014'
            }
        ],
        'skills': ['Python', 'Java', 'SQL', 'Git', 'REST APIs'],
        'work_experience': [
            {
                'role': 'Software Engineer',
                'company': 'Google',
                'start_date': '2018',
                'end_date': 'Present',
                'summary': [
                    'Developed scalable backend systems.',
                    'Optimized algorithms for performance.'
                ]
            },
            {
                'role': 'Senior Software Engineer',
                'company': 'Innovate LLC',
                'start_date': '2014',
                'end_date': '2018',
                'summary': 'Led a team of developers, designed scalable architecture, and improved overall system performance.'
            }
        ]
    }
    
    create_resume(user_details)
# Out:
# Resume saved as resume.docx
